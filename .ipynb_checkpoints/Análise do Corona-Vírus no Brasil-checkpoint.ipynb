# %% [markdown]
# # Análise de Casos de Covid no Brasil

# %% [markdown]
# ## Instalando e Importando Bibliotecas

# %%
# !pip install pandas
# !pip install sklearn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from pandas) (1.22.2)
# Requirement already satisfied: six>=1.5 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: sklearn in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from scikit-learn->sklearn) (1.8.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from scikit-learn->sklearn) (1.22.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: matplotlib in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from matplotlib) (1.22.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\doriel\miniconda3\envs\projeto\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#Importando as bibliotecas

import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Importando os Datasets

# %%
#Importando os datasets

#df_ci_coo = brazil_cities_coordinates
#df_co_ci = brazil_covid19_cities
#df_co_ma = brazil_covid19_macro
#df_co_old = brazil_covid19_old
#df_co_re = brazil_covid19_region
#df_po_2019 = brazil_population_2019

df_ci_coo = pd.read_csv("./dados/brazil_cities_coordinates.csv")
df_co_ci = pd.read_csv("./dados/brazil_covid19_cities.csv")
df_co_ma = pd.read_csv("./dados/brazil_covid19_macro.csv")
df_co_old = pd.read_csv("./dados/brazil_covid19_old.csv")
df_co_re = pd.read_csv("./dados/brazil_covid19_region.csv")
df_po_2019 = pd.read_csv("./dados/brazil_population_2019.csv", on_bad_lines='skip')

# %% [markdown]
# ## Trabalhando com o DataSet : Covid19 Macro no Brasil

# %%
df_co_ma.tail(10)
# Out:
#            date country  week       cases  deaths   recovered  monitoring
# 446  2021-05-14  Brasil    19  15519525.0  432628  14028355.0   1058542.0
# 447  2021-05-15  Brasil    19  15586534.0  434715  14062396.0   1089423.0
# 448  2021-05-16  Brasil    20  15627475.0  435751  14097287.0   1094437.0
# 449  2021-05-17  Brasil    20  15657391.0  436537  14152433.0   1068421.0
# 450  2021-05-18  Brasil    20  15732836.0  439050  14247609.0   1046177.0
# 451  2021-05-19  Brasil    20  15812055.0  441691  14330118.0   1040246.0
# 452  2021-05-20  Brasil    20  15894094.0  444094  14385962.0   1064038.0
# 453  2021-05-21  Brasil    20  15970949.0  446309  14422209.0   1102431.0
# 454  2021-05-22  Brasil    20  16047439.0  448208  14462432.0   1136799.0
# 455  2021-05-23  Brasil    21  16083258.0  449068  14492167.0   1142023.0

# %%
#Renomeando as colunas

df_co_ma_troca = {
    "date" : "data",
    "week" : "semana",
    "country" : "pais",
    "cases" : "casos",
    "deaths" : "mortes",
    "recovered" : "recuperados",
    "monitoring" : "monitorados"
}

df_co_ma = df_co_ma.rename(columns=df_co_ma_troca)
df_co_ma.head()
# Out:
#          data    pais  semana  casos  mortes  recuperados  monitorados
# 0  2020-02-25  Brasil       9    0.0       0          NaN          NaN
# 1  2020-02-26  Brasil       9    1.0       0          NaN          NaN
# 2  2020-02-27  Brasil       9    1.0       0          NaN          NaN
# 3  2020-02-28  Brasil       9    1.0       0          NaN          NaN
# 4  2020-02-29  Brasil       9    2.0       0          NaN          NaN

# %% [markdown]
# ## Analisando Outliers

# %%
plt.boxplot(df_co_ma.mortes)
plt.show()

# %%
plt.boxplot(df_co_ma.casos)
plt.show()

# %% [markdown]
# Não encontrado Outliers

# %% [markdown]
# ## Verificando dados nulos

# %%
df_co_ma.isnull().sum()
# Out:
# data            0
# pais            0
# semana          0
# casos           0
# mortes          0
# recuperados    55
# monitorados    55
# dtype: int64

# %%
df_co_ma.fillna(0, inplace = True)
df_co_ma.head()
# Out:
#          data    pais  semana  casos  mortes  recuperados  monitorados
# 0  2020-02-25  Brasil       9    0.0       0          0.0          0.0
# 1  2020-02-26  Brasil       9    1.0       0          0.0          0.0
# 2  2020-02-27  Brasil       9    1.0       0          0.0          0.0
# 3  2020-02-28  Brasil       9    1.0       0          0.0          0.0
# 4  2020-02-29  Brasil       9    2.0       0          0.0          0.0

# %% [markdown]
# Substituindo os dados nulos de recuperados e monitorados para 0, pois no momento em que eles estavam nulos era o momento que não tinhamos casos de covid em alta para acompanhamento.

# %% [markdown]
# ## Análise de letalidade da Covid19

# %%
#Deletando a coluna pais, pois a mesma se refe apenas ao Brasil

df_co_ma = df_co_ma.drop(columns = ["pais"], axis = 1)
df_co_ma.head(25)
# Out:
#           data  semana  casos  mortes  recuperados  monitorados
# 0   2020-02-25       9    0.0       0          0.0          0.0
# 1   2020-02-26       9    1.0       0          0.0          0.0
# 2   2020-02-27       9    1.0       0          0.0          0.0
# 3   2020-02-28       9    1.0       0          0.0          0.0
# 4   2020-02-29       9    2.0       0          0.0          0.0
# 5   2020-03-01      10    2.0       0          0.0          0.0
# 6   2020-03-02      10    2.0       0          0.0          0.0
# 7   2020-03-03      10    2.0       0          0.0          0.0
# 8   2020-03-04      10    3.0       0          0.0          0.0
# 9   2020-03-05      10    7.0       0          0.0          0.0
# 10  2020-03-06      10   13.0       0          0.0          0.0
# 11  2020-03-07      10   19.0       0          0.0          0.0
# 12  2020-03-08      11   25.0       0          0.0          0.0
# 13  2020-03-09      11   25.0       0          0.0          0.0
# 14  2020-03-10      11   34.0       0          0.0          0.0
# 15  2020-03-11      11   52.0       0          0.0          0.0
# 16  2020-03-12      11   77.0       0          0.0          0.0
# 17  2020-03-13      11   98.0       0          0.0          0.0
# 18  2020-03-14      11  121.0       0          0.0          0.0
# 19  2020-03-15      12  200.0       0          0.0          0.0
# 20  2020-03-16      12  234.0       0          0.0          0.0
# 21  2020-03-17      12  291.0       1          0.0          0.0
# 22  2020-03-18      12  428.0       4          0.0          0.0
# 23  2020-03-19      12  621.0       6          0.0          0.0
# 24  2020-03-20      12  904.0      11          0.0          0.0

# %%
print(type(df_co_ma.data[0]))
# Out:
# <class 'str'>

# %%
#Alterando a coluna data que está no formato string para o timestamp

df_co_ma['data'] = pd.to_datetime(df_co_ma['data'], format='%Y-%m-%d')
df_co_ma.data[1].year
# Out:
# 2020

# %%
#Com a funao dt(datetime) seleciono apenas o que necessito nesse caso foi o year(ano)

df_co_ma["data"].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 451    2021
# 452    2021
# 453    2021
# 454    2021
# 455    2021
# Name: data, Length: 456, dtype: int64

# %%
#Crio a coluna ano e visualizo o dataset

df_co_ma["ano"] = df_co_ma["data"].dt.year
df_co_ma.head()
# Out:
#         data  semana  casos  mortes  recuperados  monitorados   ano
# 0 2020-02-25       9    0.0       0          0.0          0.0  2020
# 1 2020-02-26       9    1.0       0          0.0          0.0  2020
# 2 2020-02-27       9    1.0       0          0.0          0.0  2020
# 3 2020-02-28       9    1.0       0          0.0          0.0  2020
# 4 2020-02-29       9    2.0       0          0.0          0.0  2020

# %%
df_2020 = df_co_ma.ano == 2020
df_2021 = df_co_ma.ano == 2021

# %%
df_2020
df_co_ma[df_2020]
df_co_ma_2020 = df_co_ma[df_2020]
df_co_ma_2020.head()
# Out:
#         data  semana  casos  mortes  recuperados  monitorados   ano
# 0 2020-02-25       9    0.0       0          0.0          0.0  2020
# 1 2020-02-26       9    1.0       0          0.0          0.0  2020
# 2 2020-02-27       9    1.0       0          0.0          0.0  2020
# 3 2020-02-28       9    1.0       0          0.0          0.0  2020
# 4 2020-02-29       9    2.0       0          0.0          0.0  2020

# %%
df_2021
df_co_ma[df_2021]
df_co_ma_2021 = df_co_ma[df_2021]
df_co_ma_2021.head()
# Out:
#           data  semana      casos  mortes  recuperados  monitorados   ano
# 312 2021-01-01      53  7700578.0  195411    6756284.0     748883.0  2021
# 313 2021-01-02      53  7716405.0  195725    6769420.0     751260.0  2021
# 314 2021-01-03       1  7733746.0  196018    6813008.0     724720.0  2021
# 315 2021-01-04       1  7753752.0  196561    6875230.0     681961.0  2021
# 316 2021-01-05       1  7810400.0  197732    6963407.0     649261.0  2021

# %%
#Criando o agrupamento das semanas e anos

df_sem_2020 = df_co_ma_2020.groupby(by=['semana']).sum()
df_sem_2021 = df_co_ma_2021.groupby(by=['semana']).sum()

# %%
df_sem_2020 = df_sem_2020.drop(columns = ["ano"])
df_sem_2020.head()
# Out:
#           casos  mortes  recuperados  monitorados
# semana
# 9           5.0       0          0.0          0.0
# 10         48.0       0          0.0          0.0
# 11        432.0       0          0.0          0.0
# 12       3806.0      40          0.0          0.0
# 13      18306.0     445          0.0          0.0

# %%
df_sem_2021 = df_sem_2021.drop(columns = ["ano"])
df_sem_2021.head()
# Out:
#              casos   mortes  recuperados  monitorados
# semana
# 1       55223107.0  1393874   49043591.0    4785642.0
# 2       66118956.0  1647935   58332846.0    6078550.0
# 3       60479524.0  1490303   52751119.0    6238102.0
# 4       63000377.0  1541898   54922047.0    6536432.0
# 5       65398144.0  1593316   57485040.0    6319788.0

# %%
letalidade_2020 = df_sem_2020.mortes / df_sem_2020.casos

# %%
letalidade_2020
# Out:
# semana
# 9     0.000000
# 10    0.000000
# 11    0.000000
# 12    0.010510
# 13    0.024309
# 14    0.037569
# 15    0.050670
# 16    0.061190
# 17    0.065892
# 18    0.069237
# 19    0.068310
# 20    0.068523
# 21    0.064902
# 22    0.061065
# 23    0.055420
# 24    0.051387
# 25    0.048520
# 26    0.045113
# 27    0.041812
# 28    0.039661
# 29    0.038307
# 30    0.037086
# 31    0.035273
# 32    0.033967
# 33    0.032871
# 34    0.032145
# 35    0.031616
# 36    0.030916
# 37    0.030553
# 38    0.030305
# 39    0.030045
# 40    0.029873
# 41    0.029662
# 42    0.029497
# 43    0.029302
# 44    0.028994
# 45    0.028807
# 46    0.028485
# 47    0.028129
# 48    0.027689
# 49    0.027115
# 50    0.026581
# 51    0.026084
# 52    0.025662
# 53    0.025476
# dtype: float64

# %%
letalidade_2021 = df_sem_2021.mortes / df_sem_2021.casos

# %%
letalidade_2021
# Out:
# semana
# 1     0.025241
# 2     0.024924
# 3     0.024641
# 4     0.024474
# 5     0.024363
# 6     0.024317
# 7     0.024283
# 8     0.024211
# 9     0.024171
# 10    0.024159
# 11    0.024358
# 12    0.024646
# 13    0.025207
# 14    0.025836
# 15    0.026463
# 16    0.026994
# 17    0.027421
# 18    0.027733
# 19    0.027858
# 20    0.027917
# 21    0.027921
# 53    0.025370
# dtype: float64

# %%
from matplotlib import pyplot as plt

# %%
figs, axis = plt.subplots(1,2)

axis[0].plot(letalidade_2020.values)
axis[0].set_xlabel("Semana")
axis[0].set_ylabel("Letalidade")
axis[1].plot(letalidade_2021.values)
axis[1].set_xlabel("Semana")
axis[1].set_ylabel("Letalidade")
plt.subplots_adjust(bottom=0.1, right=2.0, top=1.0)
plt.show()
